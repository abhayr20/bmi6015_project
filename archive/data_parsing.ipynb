# %%
import pandas as pd
import numpy as np

from pybioportal import studies as std
from pybioportal import clinical_data as cd
from pybioportal import clinical_attributes as ca

# %%
path = '/mnt/c/Users/u1531276/Desktop/coursework/bmi6015_applied_ml/final_project/raw_data/'

# %%
#Study Information
luad_studies = std.get_all_studies(keyword="luad", projection="DETAILED")
tcga_luad_study = std.get_study(study_id="luad_tcga_pan_can_atlas_2018")
tcga_pan_lung_study = std.get_study(study_id="nsclc_tcga_broad_2016")    # TCGA study
oncosg_luad_study = std.get_study(study_id="luad_oncosg_2020")    # Asian LUAD
sherlock_luad_study = std.get_study(study_id="lung_nci_2022")     # non-smoker Caucasian LUAD

# %%
tcga_clin_att = ca.get_all_clinical_attributes_in_study(study_id="nsclc_tcga_broad_2016", projection="DETAILED")
oncosg_clin_att = ca.get_all_clinical_attributes_in_study(study_id="luad_oncosg_2020", projection="DETAILED")
sherlock_clin_att = ca.get_all_clinical_attributes_in_study(study_id="lung_nci_2022", projection="DETAILED")

# %% [markdown]
# ## Clinical data: TCGA lung cancer study

# %%
tcga_df1 = cd.fetch_all_clinical_data_in_study(study_id="luad_tcga_pan_can_atlas_2018",
                                               attribute_ids= ['AGE', 'OS_MONTHS', 'OS_STATUS', 'SEX', 'RACE'] ,
                                               clinical_data_type="PATIENT",
                                               ret_format="WIDE")

tcga_df2 = cd.fetch_all_clinical_data_in_study(study_id="nsclc_tcga_broad_2016",
                                               attribute_ids= ['SMOKING_HISTORY', 'STAGE'] ,
                                               clinical_data_type="PATIENT",
                                               ret_format="WIDE")

tcga_df3 = cd.fetch_all_clinical_data_in_study(study_id="nsclc_tcga_broad_2016",
                                               attribute_ids= ["CANCER_TYPE_DETAILED"],
                                               clinical_data_type="SAMPLE",
                                               ret_format="WIDE")

# %%
tcga_df = tcga_df1.merge(tcga_df2, on='patientId', how='inner')
tcga_df = tcga_df.merge(tcga_df3, on='patientId', how='inner')

cols = ['patientId', 'studyId', 'SEX', "AGE", 'RACE', "CANCER_TYPE_DETAILED", 'SMOKING_HISTORY', 'STAGE', "OS_MONTHS", 'OS_STATUS']
tcga_df = tcga_df[cols]

# Rename the columns
tcga_df.rename(columns={
    'patientId': 'patient_id',
    'studyId': 'study_id',
    'SEX': 'sex',
    'AGE': 'age',
    'RACE': 'race',
    'CANCER_TYPE_DETAILED': 'histology',
    'SMOKING_HISTORY': 'smoking_status',
    'STAGE': 'stage',
    'OS_MONTHS': 'survival_months',
    'OS_STATUS': 'survival_status'
}, inplace=True)

tcga_df
# Out:
# clinicalAttributeId    patient_id               study_id     sex age  \
# 0                    TCGA-44-4112  nsclc_tcga_broad_2016  Female  60
# 1                    TCGA-44-5644  nsclc_tcga_broad_2016  Female  51
# 2                    TCGA-44-5645  nsclc_tcga_broad_2016  Female  61
# 3                    TCGA-44-5643  nsclc_tcga_broad_2016    Male  53
# 4                    TCGA-44-6144  nsclc_tcga_broad_2016    Male  58
# ..                            ...                    ...     ...  ..
# 490                  TCGA-NJ-A55A  nsclc_tcga_broad_2016  Female  76
# 491                  TCGA-NJ-A55O  nsclc_tcga_broad_2016  Female  56
# 492                  TCGA-NJ-A55R  nsclc_tcga_broad_2016    Male  67
# 493                  TCGA-O1-A52J  nsclc_tcga_broad_2016  Female  74
# 494                  TCGA-S2-AA1A  nsclc_tcga_broad_2016  Female  68
#
# clinicalAttributeId                       race            histology  \
# 0                                        White  Lung Adenocarcinoma
# 1                                        White  Lung Adenocarcinoma
# 2                    Black or African American  Lung Adenocarcinoma
# 3                    Black or African American  Lung Adenocarcinoma
# 4                                        White  Lung Adenocarcinoma
# ..                                         ...                  ...
# 490                                      White  Lung Adenocarcinoma
# 491                                      White  Lung Adenocarcinoma
# 492                                      White  Lung Adenocarcinoma
# 493                                      White  Lung Adenocarcinoma
# 494                  Black or African American  Lung Adenocarcinoma
#
# clinicalAttributeId                               smoking_status stage  \
# 0                         Current Reformed Smoker For > 15 Years    IB
# 1                                                 Current Smoker    IB
# 2                         Current Reformed Smoker For > 15 Years    IA
# 3                                                 Current Smoker  IIIA
# 4                                                 Current Smoker    IA
# ..                                                           ...   ...
# 490                       Current Reformed Smoker For > 15 Years    IB
# 491                  Current Reformed Smoker For < Or = 15 Years   IIA
# 492                       Current Reformed Smoker For > 15 Years    IA
# 493                       Current Reformed Smoker For > 15 Years    IA
# 494                       Current Reformed Smoker For > 15 Years    IA
#
# clinicalAttributeId survival_months survival_status
# 0                       26.56409245      1:DECEASED
# 1                       28.37229181        0:LIVING
# 2                       28.01065194        0:LIVING
# 3                       33.30374462        0:LIVING
# 4                       23.76960253        0:LIVING
# ..                              ...             ...
# 490                     0.493145281        0:LIVING
# 491                     0.427392577        0:LIVING
# 492                     19.82444028        0:LIVING
# 493                     59.11168097      1:DECEASED
# 494                      16.8655686        0:LIVING
#
# [495 rows x 10 columns]

# %% [markdown]
# ## Clinical data: OncoSG lung cancer study

# %%
oncosg_df = cd.fetch_all_clinical_data_in_study(study_id="luad_oncosg_2020",
                                           clinical_data_type="PATIENT", ret_format="WIDE")

oncosg_df["CANCER_TYPE_DETAILED"] = 'LUAD'
cols = ['patientId', 'studyId', 'SEX', "AGE", 'ETHNICITY', "CANCER_TYPE_DETAILED", 'SMOKING_STATUS', 'STAGE', "OS_MONTHS", 'OS_STATUS']


oncosg_df = oncosg_df[cols]

oncosg_df.rename(columns={
    'patientId': 'patient_id',
    'studyId': 'study_id',
    'SEX': 'sex',
    'AGE': 'age',
    'ETHNICITY': 'race',
    'CANCER_TYPE_DETAILED': 'histology',
    'SMOKING_STATUS': 'smoking_status',
    'STAGE': 'stage',
    'OS_MONTHS': 'survival_months',
    'OS_STATUS': 'survival_status'
}, inplace=True)

oncosg_df
# Out:
# clinicalAttributeId patient_id          study_id     sex age     race  \
# 0                         A062  luad_oncosg_2020    Male  74  Chinese
# 1                         A063  luad_oncosg_2020  Female  70  Chinese
# 2                         A066  luad_oncosg_2020  Female  72  Chinese
# 3                         A068  luad_oncosg_2020  Female  79  Chinese
# 4                         A071  luad_oncosg_2020  Female  76  Chinese
# ..                         ...               ...     ...  ..      ...
# 300                   BGI-WG20  luad_oncosg_2020    Male  62  Chinese
# 301                   BGI-WG21  luad_oncosg_2020  Female  41  Chinese
# 302                   BGI-WG22  luad_oncosg_2020  Female  34  Chinese
# 303                   BGI-WG23  luad_oncosg_2020    Male  73  Chinese
# 304                   BGI-WG24  luad_oncosg_2020    Male  67  Chinese
#
# clinicalAttributeId histology smoking_status stage survival_months  \
# 0                        LUAD             No    IV     53.46666667
# 1                        LUAD             No     I     51.13333333
# 2                        LUAD             No     I     51.33333333
# 3                        LUAD             No     I            51.0
# 4                        LUAD             No     I     52.36666667
# ..                        ...            ...   ...             ...
# 300                      LUAD             No   III             7.0
# 301                      LUAD             No    II             6.0
# 302                      LUAD             No   III            24.0
# 303                      LUAD             No   III            16.0
# 304                      LUAD            Yes    IV            17.0
#
# clinicalAttributeId survival_status
# 0                          0:LIVING
# 1                          0:LIVING
# 2                          0:LIVING
# 3                          0:LIVING
# 4                          0:LIVING
# ..                              ...
# 300                        0:LIVING
# 301                        0:LIVING
# 302                        0:LIVING
# 303                        0:LIVING
# 304                        0:LIVING
#
# [305 rows x 10 columns]

# %% [markdown]
# ## Clinical data: Sherlock lung cancer study

# %%
sherlock_df = cd.fetch_all_clinical_data_in_study(study_id="lung_nci_2022",
                                           clinical_data_type="PATIENT", ret_format="WIDE")

# %%
sherlock_df['ETHNICITY'] = 'caucasian'
sherlock_df['SMOKING_STATUS'] = 'non_smoker'
cols = ['patientId', 'studyId', 'SEX', "AGE", 'ETHNICITY', "HISTOLOGY", 'SMOKING_STATUS', 'TUMOR_STAGE', "OS_MONTHS", 'OS_STATUS']
sherlock_df = sherlock_df[cols]

sherlock_df.rename(columns={
    'patientId': 'patient_id',
    'studyId': 'study_id',
    'SEX': 'sex',
    'AGE': 'age',
    'ETHNICITY': 'race',
    'HISTOLOGY': 'histology',
    'SMOKING_STATUS': 'smoking_status',
    'TUMOR_STAGE': 'stage',
    'OS_MONTHS': 'survival_months',
    'OS_STATUS': 'survival_status'
}, inplace=True)

sherlock_df
# Out:
# clinicalAttributeId patient_id       study_id     sex  age       race  \
# 0                    NSLC-0004  lung_nci_2022  Female   69  caucasian
# 1                    NSLC-0005  lung_nci_2022  Female   66  caucasian
# 2                    NSLC-0006  lung_nci_2022    Male   36  caucasian
# 3                    NSLC-0007  lung_nci_2022  Female   72  caucasian
# 4                    NSLC-0008  lung_nci_2022  Female   77  caucasian
# ..                         ...            ...     ...  ...        ...
# 227                  NSLC-0255  lung_nci_2022    Male  NaN  caucasian
# 228                  NSLC-0250  lung_nci_2022  Female   71  caucasian
# 229                  NSLC-0251  lung_nci_2022    Male   59  caucasian
# 230                  NSLC-0252  lung_nci_2022  Female  NaN  caucasian
# 231                  NSLC-0253  lung_nci_2022  Female  NaN  caucasian
#
# clinicalAttributeId        histology smoking_status stage survival_months  \
# 0                    Adenocarcinomas     non_smoker    IA           197.9
# 1                    Adenocarcinomas     non_smoker   III            26.6
# 2                         Carcinoids     non_smoker    IA           194.4
# 3                    Adenocarcinomas     non_smoker    IB           114.3
# 4                    Adenocarcinomas     non_smoker    IA            18.6
# ..                               ...            ...   ...             ...
# 227                  Adenocarcinomas     non_smoker    IB             NaN
# 228                  Adenocarcinomas     non_smoker    IB             NaN
# 229                  Adenocarcinomas     non_smoker   III             NaN
# 230                  Adenocarcinomas     non_smoker    IA             NaN
# 231                  Adenocarcinomas     non_smoker    IB             NaN
#
# clinicalAttributeId survival_status
# 0                          0:LIVING
# 1                        1:DECEASED
# 2                          0:LIVING
# 3                        1:DECEASED
# 4                        1:DECEASED
# ..                              ...
# 227                        0:LIVING
# 228                        0:LIVING
# 229                        0:LIVING
# 230                        0:LIVING
# 231                        0:LIVING
#
# [232 rows x 10 columns]

# %%
sherlock_df['stage'].value_counts()
# Out:
# stage
# IA     94
# IB     49
# II     44
# III    38
# Name: count, dtype: int64

# %% [markdown]
# ## Combine Clinical data

# %%
clinical_df = pd.concat([tcga_df, oncosg_df, sherlock_df], axis=0, ignore_index=True)
clinical_df = clinical_df.applymap(lambda x: x.lower() if isinstance(x, str) else x)
clinical_df
# Out:
# /tmp/ipykernel_3265/1743130261.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   clinical_df = clinical_df.applymap(lambda x: x.lower() if isinstance(x, str) else x)
# clinicalAttributeId    patient_id               study_id     sex  age  \
# 0                    tcga-44-4112  nsclc_tcga_broad_2016  female   60
# 1                    tcga-44-5644  nsclc_tcga_broad_2016  female   51
# 2                    tcga-44-5645  nsclc_tcga_broad_2016  female   61
# 3                    tcga-44-5643  nsclc_tcga_broad_2016    male   53
# 4                    tcga-44-6144  nsclc_tcga_broad_2016    male   58
# ...                           ...                    ...     ...  ...
# 1027                    nslc-0255          lung_nci_2022    male  NaN
# 1028                    nslc-0250          lung_nci_2022  female   71
# 1029                    nslc-0251          lung_nci_2022    male   59
# 1030                    nslc-0252          lung_nci_2022  female  NaN
# 1031                    nslc-0253          lung_nci_2022  female  NaN
#
# clinicalAttributeId                       race            histology  \
# 0                                        white  lung adenocarcinoma
# 1                                        white  lung adenocarcinoma
# 2                    black or african american  lung adenocarcinoma
# 3                    black or african american  lung adenocarcinoma
# 4                                        white  lung adenocarcinoma
# ...                                        ...                  ...
# 1027                                 caucasian      adenocarcinomas
# 1028                                 caucasian      adenocarcinomas
# 1029                                 caucasian      adenocarcinomas
# 1030                                 caucasian      adenocarcinomas
# 1031                                 caucasian      adenocarcinomas
#
# clinicalAttributeId                          smoking_status stage  \
# 0                    current reformed smoker for > 15 years    ib
# 1                                            current smoker    ib
# 2                    current reformed smoker for > 15 years    ia
# 3                                            current smoker  iiia
# 4                                            current smoker    ia
# ...                                                     ...   ...
# 1027                                             non_smoker    ib
# 1028                                             non_smoker    ib
# 1029                                             non_smoker   iii
# 1030                                             non_smoker    ia
# 1031                                             non_smoker    ib
#
# clinicalAttributeId survival_months survival_status
# 0                       26.56409245      1:deceased
# 1                       28.37229181        0:living
# 2                       28.01065194        0:living
# 3                       33.30374462        0:living
# 4                       23.76960253        0:living
# ...                             ...             ...
# 1027                            NaN        0:living
# 1028                            NaN        0:living
# 1029                            NaN        0:living
# 1030                            NaN        0:living
# 1031                            NaN        0:living
#
# [1032 rows x 10 columns]

# %%
clinical_df['stage'].value_counts()
# Out:
# stage
# ia      225
# ib      180
# i       141
# iii     129
# ii      102
# iiia     71
# iib      68
# iia      50
# iv       44
# iiib     11
# Name: count, dtype: int64

# %%
clinical_df['race'] = clinical_df['race'].replace({
    'white': 'caucasian',
    'caucasian': 'caucasian',
    'black or african american': 'african_american',
    'chinese': 'asian',
    'asian': 'asian',
    'american indian or alaska native': 'other',
    'hispanic': 'other',
    'other': 'other'
})

clinical_df['histology'] = clinical_df['histology'].replace({
    'lung adenocarcinoma': 'luad',
    'luad': 'luad',
    'adenocarcinomas': 'luad'
})

clinical_df['smoking_status'] = clinical_df['smoking_status'].replace({
    'current reformed smoker for > 15 years': 'smoker',
    'current smoker': 'smoker',
    'current reformed smoker for < or = 15 years': 'smoker',
    'current reformed smoker, duration not specified': 'smoker',
    'yes': 'smoker',
    'lifelong non-smoker': 'non_smoker',
    'no': 'non_smoker'
})

clinical_df['survival_status'] = clinical_df['survival_status'].replace({
    '1:deceased': 1,
    '0:living': 0
})

clinical_df['stage'] = clinical_df['stage'].replace({
    'i': 'stage_1',
    'ia': 'stage_1',
    'ib': 'stage_1',
    'ii': 'stage_2',
    'iia': 'stage_2',
    'iib': 'stage_2',
    'iiia': 'stage_3',
    'iiib': 'stage_3',
    'iii': 'stage_3',
    'iv': 'stage_4'
})

clinical_df = clinical_df[~clinical_df['histology'].str.contains('carcinoids|others', na=False)]
# Out:
# /tmp/ipykernel_3265/1415793764.py:28: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   clinical_df['survival_status'] = clinical_df['survival_status'].replace({

# %%
clinical_df['patient_id'] = clinical_df['patient_id'].astype(str)

clinical_df['age'] = pd.to_numeric(clinical_df['age'], errors='coerce')
clinical_df['survival_months'] = pd.to_numeric(clinical_df['survival_months'], errors='coerce')

categorical_columns = ['sex', 'race', 'histology', 'smoking_status', 'stage', 'survival_status']
clinical_df[categorical_columns] = clinical_df[categorical_columns].apply(lambda x: x.astype('category'))
# Out:
# /tmp/ipykernel_3265/73055678.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clinical_df['patient_id'] = clinical_df['patient_id'].astype(str)
# /tmp/ipykernel_3265/73055678.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clinical_df['age'] = pd.to_numeric(clinical_df['age'], errors='coerce')
# /tmp/ipykernel_3265/73055678.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clinical_df['survival_months'] = pd.to_numeric(clinical_df['survival_months'], errors='coerce')
# /tmp/ipykernel_3265/73055678.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clinical_df[categorical_columns] = clinical_df[categorical_columns].apply(lambda x: x.astype('category'))

# %%
for col in categorical_columns:
    print(f"Unique values in {col}:")
    print(clinical_df[col].unique())
    print()
# Out:
# Unique values in sex:
# ['female', 'male']
# Categories (2, object): ['female', 'male']
#
# Unique values in race:
# ['caucasian', 'african_american', NaN, 'asian', 'other']
# Categories (4, object): ['african_american', 'asian', 'caucasian', 'other']
#
# Unique values in histology:
# ['luad']
# Categories (1, object): ['luad']
#
# Unique values in smoking_status:
# ['smoker', 'non_smoker', NaN]
# Categories (2, object): ['non_smoker', 'smoker']
#
# Unique values in stage:
# ['stage_1', 'stage_3', 'stage_2', 'stage_4', NaN]
# Categories (4, object): ['stage_1', 'stage_2', 'stage_3', 'stage_4']
#
# Unique values in survival_status:
# [1.0, 0.0, NaN]
# Categories (2, float64): [0.0, 1.0]

# %% [markdown]
# ## Add EGFR positivity data

# %%
egfr = pd.read_csv(path + 'EGFR_pos.tsv', sep='\t')
egfr_pos = egfr['Patient ID'].str.lower().tolist()

kras = pd.read_csv(path + 'kras_pos.tsv', sep='\t')
kras_pos = kras['Patient ID'].str.lower().tolist()

tp53 = pd.read_csv(path + 'tp53_pos.tsv', sep='\t')
tp53_pos = tp53['Patient ID'].str.lower().tolist()

# %%
clinical_df['egfr_mutated'] = clinical_df['patient_id'].apply(lambda x: 'egfr_pos' if x in egfr_pos else 'egfr_neg')
clinical_df['kras_mutated'] = clinical_df['patient_id'].apply(lambda x: 'kras_pos' if x in kras_pos else 'kras_neg')
clinical_df['tp53_mutated'] = clinical_df['patient_id'].apply(lambda x: 'tp53_pos' if x in tp53_pos else 'tp53_neg')
# Out:
# /tmp/ipykernel_3265/1113921993.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clinical_df['egfr_mutated'] = clinical_df['patient_id'].apply(lambda x: 'egfr_pos' if x in egfr_pos else 'egfr_neg')
# /tmp/ipykernel_3265/1113921993.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clinical_df['kras_mutated'] = clinical_df['patient_id'].apply(lambda x: 'kras_pos' if x in kras_pos else 'kras_neg')
# /tmp/ipykernel_3265/1113921993.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clinical_df['tp53_mutated'] = clinical_df['patient_id'].apply(lambda x: 'tp53_pos' if x in tp53_pos else 'tp53_neg')

# %%
clinical_df['egfr_mutated'].value_counts()
# Out:
# egfr_mutated
# egfr_neg    716
# egfr_pos    273
# Name: count, dtype: int64

# %%
clinical_df['kras_mutated'].value_counts()
# Out:
# kras_mutated
# kras_neg    786
# kras_pos    203
# Name: count, dtype: int64

# %%
clinical_df['tp53_mutated'].value_counts()
# Out:
# tp53_mutated
# tp53_neg    593
# tp53_pos    396
# Name: count, dtype: int64

# %% [markdown]
# ## Save data

# %%
clinical_df.head()
# Out:
# clinicalAttributeId    patient_id               study_id     sex   age  \
# 0                    tcga-44-4112  nsclc_tcga_broad_2016  female  60.0
# 1                    tcga-44-5644  nsclc_tcga_broad_2016  female  51.0
# 2                    tcga-44-5645  nsclc_tcga_broad_2016  female  61.0
# 3                    tcga-44-5643  nsclc_tcga_broad_2016    male  53.0
# 4                    tcga-44-6144  nsclc_tcga_broad_2016    male  58.0
#
# clinicalAttributeId              race histology smoking_status    stage  \
# 0                           caucasian      luad         smoker  stage_1
# 1                           caucasian      luad         smoker  stage_1
# 2                    african_american      luad         smoker  stage_1
# 3                    african_american      luad         smoker  stage_3
# 4                           caucasian      luad         smoker  stage_1
#
# clinicalAttributeId  survival_months survival_status egfr_mutated  \
# 0                          26.564092             1.0     egfr_neg
# 1                          28.372292             0.0     egfr_neg
# 2                          28.010652             0.0     egfr_pos
# 3                          33.303745             0.0     egfr_neg
# 4                          23.769603             0.0     egfr_neg
#
# clinicalAttributeId kras_mutated tp53_mutated
# 0                       kras_neg     tp53_neg
# 1                       kras_neg     tp53_pos
# 2                       kras_neg     tp53_pos
# 3                       kras_neg     tp53_neg
# 4                       kras_pos     tp53_pos

# %%
clinical_df.to_csv(path + 'clinical_data.csv', index=False, na_rep='NA')
